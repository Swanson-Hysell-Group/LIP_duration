# %% [markdown]
# # Midcontinent Rift dates
#
# This notebook updates the geochronology synthesis and visualization that was published in:
#
# Swanson-Hysell, N.L., Hoaglund, S.A., Crowley, J.L., Schmitz, M.D., Zhang, Y., and Miller Jr., J.D. (2021), **Rapid emplacement of the massive Duluth Complex intrusions within the Midcontinent Rift**, *Geology*, doi:10.1130/G47873.1
#
# It includes data from that paper and from:
#
# Schoene, B., Crowley, J.L., Condon, D.J., Schmitz, M.D., and Bowring, S.A. (2006), **Reassessing the uranium decay constants for geochronology using ID-TIMS U–Pb data**, *Geochimica et Cosmochimica Acta*, 70(2), 426–445, doi:10.1016/j.gca.2005.09.007.
#
# Fairchild, L.M., Swanson-Hysell, N.L., Ramezani, J., Sprain, C.J., and Bowring, S.A. (2017), **The end of Midcontinent Rift magmatism and the paleogeography of Laurentia**, *Lithosphere*, 9(1), 117–133, doi:10.1130/L580.1.
#
# Swanson-Hysell, N.L., Ramezani, J., Fairchild, L.M., and Rose, I.R. (2019), **Failed rifting and fast drifting: Midcontinent Rift development, Laurentia's rapid motion and the driver of Grenvillian orogenesis**, *GSA Bulletin*, 131, 913–940, doi:10.1130/B31944.1.
#
# Zhang, Y., Swanson-Hysell, N.L., Schmitz, M.D., Avery, M.S., and Miller Jr., J.D. (2021), **Synchronous emplacement of the anorthosite xenolith-bearing Beaver River diabase and one of the largest lava flows on Earth**, *Geochemistry, Geophysics, Geosystems*,

# %% [markdown]
# # Import scientific Python modules

# %%
from geochron_functions import plot_dates, weighted_mean

import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)

import matplotlib
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

# %% [markdown]
# ## Import individual zircon dates for the date bar plot and calculate weighted means

# %% [markdown]
# ### PRI (Partridge River intrusion augite troctolite)

# %%
PRI = pd.read_excel('../data/Midcontinent_Rift/CAIDTIMS_DataTable_080420.xls',
                      header=6,nrows=6,names=['zircon','Th_U','206Pb_mol','206Pb_mol%','Pb*/Pbc',
                                              'Pbc','206Pb/204Pb','','','','','','','','','','',
                                              '207Pb/206Pb_date','207Pb/206Pb_date_2sigma',
                                              '207Pb/235U_date','207Pb/235U_date_2sigma',
                                              '206Pb/238U_date','206Pb/238U_date_2sigma'])
PRI['include'] = pd.Series(data=['yes','yes','yes','yes','yes','yes'])
PRI
# Out:
#   zircon      Th_U  206Pb_mol  206Pb_mol%     Pb*/Pbc       Pbc   206Pb/204Pb  \
# 0     z2  0.665204  20.738831    0.999465  598.997048  0.912757  34763.091318
# 1     z5  0.795390  15.370751    0.999298  470.376992  0.888256  26480.058244
# 2     z1  0.714043  21.496997    0.999219  414.920581  1.381772  23808.791473
# 3     z6  0.624498  12.483620    0.999191  391.978441  0.831426  22978.687310
# 4     z4  0.609620  11.022847    0.998837  271.821434  1.054866  15997.732443
# 5     z3  0.668869   4.580803    0.998332  192.103651  0.629200  11151.532746
#
#              .1        .2        .3        .4        .5        .6        .7  \
# 0 NaN  0.201468  0.076115  0.042027  1.945654  0.084024  0.185393  0.045037
# 1 NaN  0.240897  0.076087  0.041746  1.944886  0.083922  0.185388  0.044575
# 2 NaN  0.216261  0.076084  0.043480  1.944671  0.085307  0.185375  0.045624
# 3 NaN  0.189143  0.076096  0.038926  1.944592  0.083271  0.185339  0.045191
# 4 NaN  0.184637  0.076106  0.045346  1.944827  0.087321  0.185336  0.046494
# 5 NaN  0.202582  0.076132  0.055232  1.945424  0.094024  0.185329  0.047827
#
#          .8  .9  207Pb/206Pb_date  207Pb/206Pb_date_2sigma  207Pb/235U_date  \
# 0  0.967479 NaN       1098.100543                 0.840968      1096.949502
# 1  0.974036 NaN       1097.367406                 0.835439      1096.684811
# 2  0.959467 NaN       1097.285151                 0.870142      1096.610856
# 3  0.991360 NaN       1097.592711                 0.778968      1096.583583
# 4  0.952037 NaN       1097.868085                 0.907422      1096.664479
# 5  0.898106 NaN       1098.551154                 1.105137      1096.870480
#
#    207Pb/235U_date_2sigma  206Pb/238U_date  206Pb/238U_date_2sigma include
# 0                0.563532      1096.369296                0.454065     yes
# 1                0.562770      1096.341199                0.449398     yes
# 2                0.572040      1096.271661                0.459944     yes
# 3                0.558374      1096.075160                0.455501     yes
# 4                0.585555      1096.058666                0.468634     yes
# 5                0.630570      1096.024042                0.482057     yes

# %%
PRI_mean, PRI_2sigma = weighted_mean(PRI['206Pb/238U_date'].tolist(),PRI['206Pb/238U_date_2sigma'].tolist())
# Out:
# The weighted mean is:
# 1096.1949149677969
# With a 2sigma error of:
# 0.18829360877861095
# N=
# 6

# %%
weighted_mean(PRI['207Pb/206Pb_date'].tolist(),PRI['207Pb/206Pb_date_2sigma'].tolist())
# Out:
# The weighted mean is:
# 1097.7339098613106
# With a 2sigma error of:
# 0.3569444447827721
# N=
# 6
# (1097.7339098613106, 0.3569444447827721)

# %% [markdown]
# ### FC4b (Forest Center gabbroic anorthosite)

# %%
FC_4b = pd.read_excel('../data/Midcontinent_Rift/CAIDTIMS_DataTable_080420.xls',
                      header=16,nrows=8,names=['zircon','Th_U','206Pb_mol','206Pb_mol%','Pb*/Pbc',
                                              'Pbc','206Pb/204Pb','','','','','','','','','','',
                                              '207Pb/206Pb_date','207Pb/206Pb_date_2sigma',
                                              '207Pb/235U_date','207Pb/235U_date_2sigma',
                                              '206Pb/238U_date','206Pb/238U_date_2sigma'])
FC_4b['include'] = pd.Series(data=['yes','yes','yes','yes','yes','yes','yes','no'])
FC_4b
# Out:
#   zircon      Th_U  206Pb_mol  206Pb_mol%      Pb*/Pbc       Pbc  \
# 0    z10  0.732493   8.741441    0.998602   232.714287  1.006159
# 1     z2  0.685956  30.215754    0.999553   720.872893  1.110498
# 2     z4  0.705346  20.983914    0.999470   610.239491  0.915220
# 3    z11  0.716248  11.751073    0.998873   287.658581  1.090072
# 4     z3  0.637369  48.508804    0.999751  1280.248927  0.992261
# 5     z1  0.630074  18.180244    0.999420   547.799730  0.867566
# 6     z6  0.658618  12.040454    0.999194   396.896589  0.798492
# 7     z5  0.466824   9.685236    0.998807   255.684352  0.951335
#
#     206Pb/204Pb            .1        .2        .3        .4        .5  \
# 0  13303.954512 NaN  0.221854  0.076063  0.047200  1.943304  0.088769
# 1  41626.178163 NaN  0.207760  0.076108  0.041134  1.944432  0.084174
# 2  35079.063942 NaN  0.213633  0.076103  0.041576  1.944131  0.085021
# 3  16503.217227 NaN  0.216936  0.076093  0.045205  1.943756  0.087111
# 4  74775.472679 NaN  0.193046  0.076115  0.040481  1.944305  0.086180
# 5  32063.117209 NaN  0.190837  0.076078  0.041777  1.943210  0.084107
# 6  23076.985734 NaN  0.199484  0.076086  0.043555  1.943138  0.086468
# 7  15586.620064 NaN  0.141401  0.076159  0.045771  1.943271  0.087635
#
#          .6        .7        .8  .9  207Pb/206Pb_date  \
# 0  0.185297  0.046514  0.946454 NaN       1096.720099
# 1  0.185295  0.046232  0.967581 NaN       1097.903848
# 2  0.185277  0.047189  0.962973 NaN       1097.785830
# 3  0.185266  0.046228  0.953820 NaN       1097.514033
# 4  0.185265  0.050644  0.956941 NaN       1098.089814
# 5  0.185251  0.045221  0.969363 NaN       1097.117066
# 6  0.185223  0.047401  0.954788 NaN       1097.342372
# 7  0.185060  0.046373  0.951710 NaN       1099.241376
#
#    207Pb/206Pb_date_2sigma  207Pb/235U_date  207Pb/235U_date_2sigma  \
# 0                 0.944684      1096.139375                0.595111
# 1                 0.823122      1096.528319                0.564413
# 2                 0.831979      1096.424420                0.570068
# 3                 0.904642      1096.295173                0.584039
# 4                 0.810031      1096.484558                0.577856
# 5                 0.836080      1096.106997                0.563848
# 6                 0.871633      1096.081885                0.579669
# 7                 0.915732      1096.128026                0.587506
#
#    206Pb/238U_date  206Pb/238U_date_2sigma include
# 0      1095.846192                0.468752     yes
# 1      1095.835821                0.465909     yes
# 2      1095.738377                0.475511     yes
# 3      1095.680882                0.465806     yes
# 4      1095.675321                0.510301     yes
# 5      1095.599212                0.455627     yes
# 6      1095.447828                0.477528     yes
# 7      1094.561151                0.466827      no

# %%
FC_4b_filtered = FC_4b[FC_4b['include'] == 'yes']
FC4b_mean, FC4b_2sigma = weighted_mean(FC_4b_filtered['206Pb/238U_date'].tolist(),FC_4b_filtered['206Pb/238U_date_2sigma'].tolist())
# Out:
# The weighted mean is:
# 1095.68996253492
# With a 2sigma error of:
# 0.17893748108450228
# N=
# 7

# %%
weighted_mean(FC_4b_filtered['207Pb/206Pb_date'].tolist(),FC_4b_filtered['207Pb/206Pb_date_2sigma'].tolist())
# Out:
# The weighted mean is:
# 1097.531031573214
# With a 2sigma error of:
# 0.3238648206769041
# N=
# 7
# (1097.531031573214, 0.3238648206769041)

# %% [markdown]
# ### FC1 (Forest Center gabbroic anorthosite)

# %%
FC_1 = pd.read_excel('../data/Midcontinent_Rift/CAIDTIMS_DataTable_080420.xls',
                      header=28,nrows=10,names=['zircon','Th_U','206Pb_mol','206Pb_mol%','Pb*/Pbc',
                                              'Pbc','206Pb/204Pb','','','','','','','','','','',
                                              '207Pb/206Pb_date','207Pb/206Pb_date_2sigma',
                                              '207Pb/235U_date','207Pb/235U_date_2sigma',
                                              '206Pb/238U_date','206Pb/238U_date_2sigma'])
FC_1['include'] = pd.Series(data=['yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes'])
FC_1
# Out:
#   zircon      Th_U   206Pb_mol  206Pb_mol%      Pb*/Pbc       Pbc  \
# 0    z21  0.346609   89.347895    0.999927  4054.676586  0.536709
# 1    z23  1.361833   38.675195    0.999810  1968.511425  0.604166
# 2    z22  0.614343  135.133318    0.999962  8331.540030  0.422393
# 3    z26  1.443480   63.568766    0.999918  4619.958647  0.430198
# 4    z20  1.508076   98.565374    0.999919  4740.478757  0.658544
# 5    z25  0.684380   41.109875    0.999849  2138.855734  0.509040
# 6    z19  0.715076  125.901073    0.999941  5523.148853  0.608119
# 7    z27  0.546654   56.258525    0.999807  1613.937040  0.892957
# 8    z18  1.413612   46.240978    0.999797  1865.096833  0.770490
# 9    z24  1.439475   92.317512    0.999944  6768.172748  0.426115
#
#      206Pb/204Pb            .1        .2        .3        .4        .5  \
# 0  254585.737618 NaN  0.104978  0.076114  0.040011  1.945436  0.085824
# 1   97907.295233 NaN  0.412450  0.076128  0.040295  1.945645  0.085729
# 2  489236.023246 NaN  0.186069  0.076095  0.039946  1.944341  0.085691
# 3  225978.970327 NaN  0.437182  0.076115  0.040037  1.944854  0.084192
# 4  228892.387686 NaN  0.456746  0.076133  0.040032  1.945290  0.093168
# 5  123513.915634 NaN  0.207283  0.076130  0.040198  1.944934  0.083452
# 6  316608.663227 NaN  0.216582  0.076125  0.039978  1.944464  0.085099
# 7   96360.365426 NaN  0.165571  0.076142  0.040389  1.944896  0.083699
# 8   91791.963200 NaN  0.428148  0.076104  0.040343  1.943656  0.084305
# 9  331312.986492 NaN  0.435984  0.076107  0.039986  1.943493  0.084925
#
#          .6        .7        .8  .9  207Pb/206Pb_date  \
# 0  0.185375  0.050673  0.957982 NaN       1098.075509
# 1  0.185360  0.050131  0.958654 NaN       1098.447442
# 2  0.185317  0.050545  0.958392 NaN       1097.564101
# 3  0.185317  0.047834  0.965270 NaN       1098.093390
# 4  0.185315  0.062308  0.944068 NaN       1098.561883
# 5  0.185289  0.046252  0.969964 NaN       1098.479629
# 6  0.185255  0.049487  0.960828 NaN       1098.368764
# 7  0.185254  0.046503  0.968172 NaN       1098.819375
# 8  0.185230  0.047599  0.965248 NaN       1097.800136
# 9  0.185206  0.049194  0.961596 NaN       1097.900271
#
#    207Pb/206Pb_date_2sigma  207Pb/235U_date  207Pb/235U_date_2sigma  \
# 0                 0.800634      1096.874461                0.575582
# 1                 0.806270      1096.946443                0.574965
# 2                 0.799394      1096.496987                0.574579
# 3                 0.801159      1096.673976                0.564577
# 4                 0.800995      1096.824143                0.624818
# 5                 0.804322      1096.701475                0.559626
# 6                 0.799938      1096.539480                0.570621
# 7                 0.808107      1096.688323                0.561273
# 8                 0.807306      1096.260529                0.565219
# 9                 0.800155      1096.204372                0.569359
#
#    206Pb/238U_date  206Pb/238U_date_2sigma include
# 0      1096.269262                0.510845     yes
# 1      1096.190626                0.505346     yes
# 2      1095.959045                0.509420     yes
# 3      1095.958878                0.482097     yes
# 4      1095.947910                0.627970     yes
# 5      1095.806250                0.466096     yes
# 6      1095.618115                0.498619     yes
# 7      1095.615267                0.468548     yes
# 8      1095.485328                0.479545     yes
# 9      1095.351315                0.495552     yes

# %%
FC1_mean, FC1_2sigma = weighted_mean(FC_1['206Pb/238U_date'].tolist(),FC_1['206Pb/238U_date_2sigma'].tolist())
# Out:
# The weighted mean is:
# 1095.8064839177662
# With a 2sigma error of:
# 0.15803362004300317
# N=
# 10

# %%
weighted_mean(FC_1['207Pb/206Pb_date'].tolist(),FC_1['207Pb/206Pb_date_2sigma'].tolist())
# Out:
# The weighted mean is:
# 1098.209797887362
# With a 2sigma error of:
# 0.253870607708266
# N=
# 10
# (1098.209797887362, 0.253870607708266)

# %% [markdown]
# ### BEI (Bald Eagle intrusion olivine gabbro)

# %%
BEI = pd.read_excel('../data/Midcontinent_Rift/CAIDTIMS_DataTable_080420.xls',
                      header=42,nrows=6,names=['zircon','Th_U','206Pb_mol','206Pb_mol%','Pb*/Pbc',
                                              'Pbc','206Pb/204Pb','','','','','','','','','','',
                                              '207Pb/206Pb_date','207Pb/206Pb_date_2sigma',
                                              '207Pb/235U_date','207Pb/235U_date_2sigma',
                                              '206Pb/238U_date','206Pb/238U_date_2sigma'])
BEI['include'] = pd.Series(data=['yes','yes','yes','yes','yes','yes'])
BEI
# Out:
#   zircon      Th_U  206Pb_mol  206Pb_mol%     Pb*/Pbc       Pbc   206Pb/204Pb  \
# 0     z4  0.680513  16.166279    0.999059  341.789128  1.251490  19771.884380
# 1    z6a  0.648842  30.114618    0.999651  914.282088  0.864928  53260.553285
# 2    z6b  0.841343  24.905968    0.999584  803.433314  0.851613  44740.242394
# 3     z5  0.651769   4.752472    0.998288  186.418528  0.669905  10866.936150
# 4     z3  0.575568   6.727079    0.998244  178.375718  0.972931  10591.668848
# 5     z1  0.522555   5.978246    0.998057  159.135870  0.956634   9574.788902
#
#              .1        .2        .3        .4        .5        .6        .7  \
# 0 NaN  0.206107  0.076097  0.043677  1.944811  0.085082  0.185357  0.044485
# 1 NaN  0.196517  0.076078  0.045237  1.944074  0.085445  0.185332  0.045499
# 2 NaN  0.254820  0.076081  0.039295  1.944010  0.084195  0.185319  0.047651
# 3 NaN  0.197405  0.076062  0.049568  1.943397  0.090414  0.185308  0.046029
# 4 NaN  0.174326  0.076104  0.051975  1.944330  0.091373  0.185294  0.045535
# 5 NaN  0.158275  0.076119  0.053582  1.943668  0.094764  0.185195  0.049545
#
#          .8  .9  207Pb/206Pb_date  207Pb/206Pb_date_2sigma  207Pb/235U_date  \
# 0  0.965728 NaN       1097.621322                 0.874051      1096.659031
# 1  0.942047 NaN       1097.131371                 0.905329      1096.404753
# 2  0.974037 NaN       1097.210050                 0.786410      1096.382906
# 3  0.941509 NaN       1096.695065                 0.992072      1096.171437
# 4  0.927870 NaN       1097.810864                 1.040079      1096.493129
# 5  0.911999 NaN       1098.193526                 1.072177      1096.264721
#
#    207Pb/235U_date_2sigma  206Pb/238U_date  206Pb/238U_date_2sigma include
# 0                0.570539      1096.174776                0.448424     yes
# 1                0.572900      1096.038809                0.458593     yes
# 2                0.564514      1095.966354                0.480253     yes
# 3                0.606148      1095.907372                0.463888     yes
# 4                0.612679      1095.829451                0.458877     yes
# 5                0.635342      1095.292982                0.499063     yes

# %%
BEI_mean, BEI_2sigma = weighted_mean(BEI['206Pb/238U_date'].tolist(),BEI['206Pb/238U_date_2sigma'].tolist())
# Out:
# The weighted mean is:
# 1095.8845755325888
# With a 2sigma error of:
# 0.19078005572414714
# N=
# 6

# %%
weighted_mean(BEI['207Pb/206Pb_date'].tolist(),BEI['207Pb/206Pb_date_2sigma'].tolist())
# Out:
# The weighted mean is:
# 1097.4012446817937
# With a 2sigma error of:
# 0.37914805982744265
# N=
# 6
# (1097.4012446817937, 0.37914805982744265)

# %% [markdown]
# ### HCT Houghtaling Creek troctolite augite troctolite

# %%
HCT = pd.read_excel('../data/Midcontinent_Rift/CAIDTIMS_DataTable_080420.xls',
                      header=52,nrows=11,names=['zircon','Th_U','206Pb_mol','206Pb_mol%','Pb*/Pbc',
                                              'Pbc','206Pb/204Pb','','','','','','','','','','',
                                              '207Pb/206Pb_date','207Pb/206Pb_date_2sigma',
                                              '207Pb/235U_date','207Pb/235U_date_2sigma',
                                              '206Pb/238U_date','206Pb/238U_date_2sigma'])
HCT['include'] = pd.Series(data=['yes','yes','yes','yes','no','no','no','no','no','no','no'])
HCT
# Out:
#    zircon      Th_U  206Pb_mol  206Pb_mol%     Pb*/Pbc       Pbc  206Pb/204Pb  \
# 0      z7  0.764721  11.693407    0.997795  148.590148  2.124054  8437.048906
# 1      z6  0.665971   4.761950    0.996835  101.024775  1.242870  5877.497309
# 2      z1  0.395540   3.702192    0.994501   54.247538  1.683118  3382.175294
# 3     z10  0.719092   3.506297    0.996543   93.626752  1.000012  5380.271803
# 4      z4  1.566024   1.317539    0.987617   31.077112  1.358191  1502.003580
# 5      z9  1.053099   4.869438    0.997980  173.136262  0.810178  9209.435293
# 6     z12  1.398374   4.797283    0.997744  166.661643  0.891787  8244.640101
# 7     z11  0.687422   2.186194    0.994740   60.962741  0.950404  3536.123144
# 8     z14  0.403788   1.060983    0.995127   61.392763  0.427131  3817.030070
# 9      z8  2.079234   1.584600    0.992583   57.415270  0.973467  2507.772918
# 10     z5  1.078373   2.770739    0.990939   38.528680  2.082941  2052.713752
#
#               .1        .2        .3        .4        .5        .6        .7  \
# 0  NaN  0.231617  0.076148  0.054816  1.945126  0.094359  0.185263  0.046349
# 1  NaN  0.201709  0.076088  0.066774  1.943504  0.106356  0.185254  0.051201
# 2  NaN  0.119804  0.076008  0.099011  1.940861  0.138646  0.185196  0.059801
# 3  NaN  0.217804  0.076115  0.069366  1.943201  0.108273  0.185159  0.050520
# 4  NaN  0.474332  0.076022  0.209560  1.939747  0.255769  0.185058  0.082579
# 5  NaN  0.318984  0.076086  0.053514  1.940680  0.093928  0.184991  0.047531
# 6  NaN  0.423571  0.076078  0.056917  1.939859  0.097822  0.184932  0.050157
# 7  NaN  0.208227  0.076054  0.096413  1.939117  0.134773  0.184918  0.056470
# 8  NaN  0.122313  0.076053  0.085643  1.938838  0.233250  0.184895  0.202313
# 9  NaN  0.629813  0.076134  0.128243  1.940092  0.246596  0.184818  0.191170
# 10 NaN  0.326656  0.076011  0.151582  1.936924  0.192564  0.184814  0.066423
#
#           .8  .9  207Pb/206Pb_date  207Pb/206Pb_date_2sigma  207Pb/235U_date  \
# 0   0.920022 NaN       1098.958850                 1.096735      1096.767700
# 1   0.869933 NaN       1097.388864                 1.336291      1096.208325
# 2   0.783685 NaN       1095.293164                 1.982058      1095.296299
# 3   0.865074 NaN       1098.100543                 1.388030      1096.103683
# 4   0.670508 NaN       1095.640063                 4.194906      1094.911430
# 5   0.920446 NaN       1097.328067                 1.070960      1095.233677
# 6   0.901529 NaN       1097.117066                 1.139100      1094.950120
# 7   0.792135 NaN       1096.498370                 1.929697      1094.693930
# 8   0.932421 NaN       1096.462607                 1.714137      1094.597559
# 9   0.858150 NaN       1098.583341                 2.566016      1095.030500
# 10  0.723830 NaN       1095.357537                 3.034438      1093.935994
#
#     207Pb/235U_date_2sigma  206Pb/238U_date  206Pb/238U_date_2sigma include
# 0                 0.632785      1095.664310                0.467016     yes
# 1                 0.713036      1095.613548                0.515880     yes
# 2                 0.929091      1095.297235                0.602377     yes
# 3                 0.725851      1095.098899                0.508801     yes
# 4                 1.713616      1094.545660                0.831297      no
# 5                 0.629408      1094.181048                0.478328      no
# 6                 0.655408      1093.860042                0.504628      no
# 7                 0.902862      1093.786140                0.568103      no
# 8                 1.562490      1093.659915                2.035108      no
# 9                 1.652254      1093.244146                1.922347      no
# 10                1.289513      1093.221680                0.667916      no

# %%
HCT_filtered = HCT[HCT['include'] == 'yes']
HCT_mean, HCT_2sigma = weighted_mean(HCT_filtered['206Pb/238U_date'].tolist(),HCT_filtered['206Pb/238U_date_2sigma'].tolist())
# Out:
# The weighted mean is:
# 1095.4379621556755
# With a 2sigma error of:
# 0.25853320335225466
# N=
# 4

# %%
weighted_mean(HCT['207Pb/206Pb_date'].tolist(),HCT['207Pb/206Pb_date_2sigma'].tolist())
# Out:
# The weighted mean is:
# 1097.428102936908
# With a 2sigma error of:
# 0.4596197147877392
# N=
# 11
# (1097.428102936908, 0.4596197147877392)

# %% [markdown]
# ### WLFG (Wilson Lake Ferrogabbro ferrodiorite)

# %%
WLFG = pd.read_excel('../data/Midcontinent_Rift/CAIDTIMS_DataTable_080420.xls',
                      header=67,nrows=8,names=['zircon','Th_U','206Pb_mol','206Pb_mol%','Pb*/Pbc',
                                              'Pbc','206Pb/204Pb','','','','','','','','','','',
                                              '207Pb/206Pb_date','207Pb/206Pb_date_2sigma',
                                              '207Pb/235U_date','207Pb/235U_date_2sigma',
                                              '206Pb/238U_date','206Pb/238U_date_2sigma'])
WLFG['include'] = pd.Series(data=['yes','yes','yes','yes','yes','no','no','no'])
WLFG
# Out:
#   zircon      Th_U  206Pb_mol  206Pb_mol%     Pb*/Pbc       Pbc  206Pb/204Pb  \
# 0     z2  1.224601   3.644101    0.996738  111.063300  0.980568  5701.490862
# 1     z9  1.236322   1.201512    0.980587   18.408557  1.955569   958.131961
# 2    z16  1.208902   0.771680    0.987189   27.918931  0.823318  1451.864318
# 3    z26  1.115325   1.319440    0.992252   45.477806  0.847075  2400.504923
# 4    z19  2.350041   0.398676    0.971479   15.320475  0.962260   652.153967
# 5    z27  2.409834   0.711368    0.981585   24.219815  1.097206  1010.030685
# 6    z28  1.612990   0.467551    0.981962   21.409403  0.706115  1031.134181
# 7    z18  1.209867   0.241141    0.958630    8.396053  0.855564   449.597663
#
#              .1        .2        .3        .4        .5        .6        .7  \
# 0 NaN  0.370977  0.075967  0.066129  1.933162  0.105049  0.184562  0.049038
# 1 NaN  0.374529  0.076083  0.312266  1.936035  0.382628  0.184555  0.134461
# 2 NaN  0.366226  0.075998  0.204605  1.933520  0.265114  0.184521  0.114071
# 3 NaN  0.337884  0.075943  0.130765  1.931614  0.171326  0.184473  0.064427
# 4 NaN  0.711935  0.076052  0.418774  1.933129  0.516889  0.184353  0.154665
# 5 NaN  0.730155  0.076019  0.289893  1.927110  0.351124  0.183859  0.109579
# 6 NaN  0.488775  0.075879  0.298321  1.920473  0.392827  0.183562  0.193654
# 7 NaN  0.366629  0.075685  0.693197  1.915054  0.825942  0.183513  0.265967
#
#          .8  .9  207Pb/206Pb_date  207Pb/206Pb_date_2sigma  207Pb/235U_date  \
# 0  0.880164 NaN       1094.195247                 1.324029      1092.634480
# 1  0.650878 NaN       1097.249389                 6.249326      1093.628513
# 2  0.685053 NaN       1095.021367                 4.096086      1092.758355
# 3  0.743102 NaN       1093.562245                 2.618404      1092.098518
# 4  0.723818 NaN       1096.437573                 8.381948      1092.622947
# 5  0.666186 NaN       1095.564961                 5.803091      1090.537132
# 6  0.675796 NaN       1091.892123                 5.975028      1088.232224
# 7  0.619990 NaN       1086.763740                13.894494      1086.346592
#
#    207Pb/235U_date_2sigma  206Pb/238U_date  206Pb/238U_date_2sigma include
# 0                0.703000      1091.851709                0.492535     yes
# 1                2.561876      1091.809997                1.350467     yes
# 2                1.774281      1091.623287                1.145497     yes
# 3                1.146214      1091.364092                0.646834     yes
# 4                3.459052      1090.710440                1.551951     yes
# 5                2.347244      1088.021503                1.097062      no
# 6                2.622925      1086.404666                1.936135      no
# 7                5.509521      1086.138700                2.658519      no

# %%
WLFG_filtered = WLFG[WLFG['include'] == 'yes']
WLFG_mean, WLFG_2sigma = weighted_mean(WLFG_filtered['206Pb/238U_date'].tolist(),WLFG_filtered['206Pb/238U_date_2sigma'].tolist())
# Out:
# The weighted mean is:
# 1091.6288060423644
# With a 2sigma error of:
# 0.34841171503396046
# N=
# 5

# %% [markdown]
# ### Import data from MCR intrusives and volcanics from other studies

# %% [markdown]
# CA-ID-TIMS data from AS3 (Duluth Complex gabbroic anorthosite from near Duluth) were published in Schoene et al. 2006
#
# Schoene, B., Crowley, J. L., Condon, D. J., Schmitz, M. D., and Bowring, S. A., 2006, Reassessing 266 the uranium decay constants for geochronology using ID-TIMS U–Pb data: Geochimica et Cosmochimica Acta, vol. 70, pp. 426–445, doi:10.1016/j.gca.2005.09.007.

# %%
AS3 = pd.read_csv('../data/Midcontinent_Rift/AS3_dates.csv')
AS3.sort_values('206Pb/238U_date', inplace=True, ascending=False)
AS3.reset_index(inplace=True)

# %%
AS3_mean, AS3_2sigma = weighted_mean(AS3['206Pb/238U_date'].tolist(),AS3['206Pb/238U_date_2sigma'].tolist())
# Out:
# The weighted mean is:
# 1095.8622134886054
# With a 2sigma error of:
# 0.18711199066156345
# N=
# 8

# %% [markdown]
# CA-ID-TIMS data from Midcontinent Rift volcanics were published in Fairchild et al. 2017 and Swanson-Hysell et al. 2019
#
# Fairchild, L. M., Swanson-Hysell, N. L., Ramezani, J., Sprain, C. J., and Bowring, S. A., 2017, The end of Midcontinent Rift magmatism and the paleogeography of Laurentia: Lithosphere, vol. 9, pp. 117–133, doi:10.1130/L580.1.
#
# Swanson-Hysell, N. L., Ramezani, J., Fairchild, L. M., and Rose, I. R., 2019, Failed rifting and fast drifting: Midcontinent Rift development, Laurentia’s rapid motion and the driver of Grenvillian orogenesis: GSA Bulletin, doi:10.1130/b31944.1.

# %%
AP71 = pd.read_csv('../data/Midcontinent_Rift/AP71_dates.csv')
AP71.sort_values('206Pb/238U', inplace=True, ascending=False)
AP71.reset_index(inplace=True)

NSVG_RRR = pd.read_csv('../data/Midcontinent_Rift/NSVG-RRR_dates.csv')
NSVG_RRR.sort_values('206Pb/238U', inplace=True, ascending=False)
NSVG_RRR.reset_index(inplace=True)

MP111_182 = pd.read_csv('../data/Midcontinent_Rift/MP111-182_dates.csv')
MP111_182.sort_values('206Pb/238U', inplace=True, ascending=False)
MP111_182.reset_index(inplace=True)

CF1 = pd.read_csv('../data/Midcontinent_Rift/CF1_dates.csv')
CF1.sort_values('206Pb/238U', inplace=True, ascending=False)
CF1.reset_index(inplace=True)

NSVG_40I = pd.read_csv('../data/Midcontinent_Rift/NSVG-40I_dates.csv')
NSVG_40I.sort_values('206Pb/238U', inplace=True, ascending=False)
NSVG_40I.reset_index(inplace=True)

NSVG_TH1 = pd.read_csv('../data/Midcontinent_Rift/NSVG-TH1_dates.csv')
NSVG_TH1.sort_values('206Pb/238U', inplace=True, ascending=False)
NSVG_TH1.reset_index(inplace=True)

NSVG_PR = pd.read_csv('../data/Midcontinent_Rift/NSVG-PR_dates.csv')
NSVG_PR.sort_values('206Pb/238U', inplace=True, ascending=False)
NSVG_PR.reset_index(inplace=True)

NSVG_GMR1 = pd.read_csv('../data/Midcontinent_Rift/NSVG-GMR1_dates.csv')
NSVG_GMR1.sort_values('206Pb/238U', inplace=True, ascending=False)
NSVG_GMR1.reset_index(inplace=True)

PLV_CC1 = pd.read_csv('../data/Midcontinent_Rift/PLV-CC1_dates.csv')
PLV_CC1.sort_values('206Pb/238U', inplace=True, ascending=False)
PLV_CC1.reset_index(inplace=True)

PLV_GS1 = pd.read_csv('../data/Midcontinent_Rift/PLV-GS1_dates.csv')
PLV_GS1.sort_values('206Pb/238U', inplace=True, ascending=False)
PLV_GS1.reset_index(inplace=True)

LST_KP1 = pd.read_csv('../data/Midcontinent_Rift/LST-KP1_dates.csv')
LST_KP1.sort_values('206Pb/238U', inplace=True, ascending=False)
LST_KP1.reset_index(inplace=True)

MI_WSB1 = pd.read_csv('../data/Midcontinent_Rift/MI-WSB1_dates.csv')
MI_WSB1.sort_values('206Pb/238U', inplace=True, ascending=False)
MI_WSB1.reset_index(inplace=True)

MI_DI1 = pd.read_csv('../data/Midcontinent_Rift/MI-DI1_dates.csv')
MI_DI1.sort_values('206Pb/238U', inplace=True, ascending=False)
MI_DI1.reset_index(inplace=True)

BBC_SBA1 = pd.read_csv('../data/Midcontinent_Rift/BBC-SBA1_dates.csv')
BBC_SBA1.sort_values('206Pb/238U', inplace=True, ascending=False)
BBC_SBA1.reset_index(inplace=True)

MS99033 = pd.read_csv('../data/Midcontinent_Rift/MS99033_dates.csv')
MS99033.sort_values('206Pb/238U', inplace=True, ascending=False)
MS99033.reset_index(inplace=True)

# %% [markdown]
# ## Input weighted mean dates and compile data for figures
#
# Weighted means for Schoene et al. 2006, Fairchild et al. 2017, Swanson-Hysell et al. 2019 and Zhang et al. 2021 are manually entered below.

# %%
samples = [
    {
        "name": "NSVG_RRR",
        "df": NSVG_RRR,
        "date_col": "206Pb/238U",
        "sigma_col": "206Pb/238U_2sigma",
        "mean": 1105.60,
        "mean_2sigma": 0.32,
        "color": "red",
        "label": "Red Rock Rhyolite",
    },
    {
        "name": "AP71",
        "df": AP71,
        "date_col": "206Pb/238U",
        "sigma_col": "206Pb/238U_2sigma",
        "mean": 1105.15,
        "mean_2sigma": 0.33,
        "color": "red",
        "label": "Agate Point Rhyolite",
    },
    {
        "name": "MP111_182",
        "df": MP111_182,
        "date_col": "206Pb/238U",
        "sigma_col": "206Pb/238U_2sigma",
        "mean": 1100.36,
        "mean_2sigma": 0.25,
        "color": "red",
        "label": "Flour Bay tuff",
    },
    {
        "name": "CF1",
        "df": CF1,
        "date_col": "206Pb/238U",
        "sigma_col": "206Pb/238U_2sigma",
        "mean": 1098.24,
        "mean_2sigma": 0.45,
        "color": "blue",
        "label": "Kallander Creek Rhyolite",
    },
    {
        "name": "NSVG_40I",
        "df": NSVG_40I,
        "date_col": "206Pb/238U",
        "sigma_col": "206Pb/238U_2sigma",
        "mean": 1096.75,
        "mean_2sigma": 0.28,
        "color": "blue",
        "label": "40th Ave Icelandite",
    },
    {
        "name": "NSVG_TH1",
        "df": NSVG_TH1,
        "date_col": "206Pb/238U",
        "sigma_col": "206Pb/238U_2sigma",
        "mean": 1096.18,
        "mean_2sigma": 0.32,
        "color": "blue",
        "label": "Two Harbors Icelandite",
    },
    {
        "name": "NSVG_PR",
        "df": NSVG_PR,
        "date_col": "206Pb/238U",
        "sigma_col": "206Pb/238U_2sigma",
        "mean": 1093.94,
        "mean_2sigma": 0.28,
        "color": "blue",
        "label": "Palisade Rhyolite",
    },
    {
        "name": "NSVG_GMR1",
        "df": NSVG_GMR1,
        "date_col": "206Pb/238U",
        "sigma_col": "206Pb/238U_2sigma",
        "mean": 1093.52,
        "mean_2sigma": 0.43,
        "color": "blue",
        "label": "Grand Marais Rhyolite",
    },
    {
        "name": "PLV_CC1",
        "df": PLV_CC1,
        "date_col": "206Pb/238U",
        "sigma_col": "206Pb/238U_2sigma",
        "mean": 1093.37,
        "mean_2sigma": 0.53,
        "color": "blue",
        "label": "Copper City Flow",
    },
    {
        "name": "PLV_GS1",
        "df": PLV_GS1,
        "date_col": "206Pb/238U",
        "sigma_col": "206Pb/238U_2sigma",
        "mean": 1091.59,
        "mean_2sigma": 0.27,
        "color": "blue",
        "label": "Greenstone Flow",
    },
    {
        "name": "LST_KP1",
        "df": LST_KP1,
        "date_col": "206Pb/238U",
        "sigma_col": "206Pb/238U_2sigma",
        "mean": 1085.57,
        "mean_2sigma": 0.25,
        "color": "blue",
        "label": "Lake Shore Trap andesite",
    },
    {
        "name": "MI_WSB1",
        "df": MI_WSB1,
        "date_col": "206Pb/238U",
        "sigma_col": "206Pb/238U_2sigma",
        "mean": 1084.35,
        "mean_2sigma": 0.20,
        "color": "blue",
        "label": "West Sand Bay Tuff",
    },
    {
        "name": "MI_DI1",
        "df": MI_DI1,
        "date_col": "206Pb/238U",
        "sigma_col": "206Pb/238U_2sigma",
        "mean": 1083.52,
        "mean_2sigma": 0.23,
        "color": "blue",
        "label": "Davieux Island Rhyolite",
    },
    # ----- date columns with "_date" / "_date_2sigma" -----
    {
        "name": "PRI",
        "df": PRI,
        "date_col": "206Pb/238U_date",
        "sigma_col": "206Pb/238U_date_2sigma",
        "mean": PRI_mean,
        "mean_2sigma": PRI_2sigma,
        "color": "darkblue",
        "label": "Partridge River intrusion",
    },
    {
        "name": "BEI",
        "df": BEI,
        "date_col": "206Pb/238U_date",
        "sigma_col": "206Pb/238U_date_2sigma",
        "mean": BEI_mean,
        "mean_2sigma": BEI_2sigma,
        "color": "darkblue",
        "label": "Bald Eagle intrusion",
    },
    {
        "name": "AS3",
        "df": AS3,
        "date_col": "206Pb/238U_date",
        "sigma_col": "206Pb/238U_date_2sigma",
        "mean": AS3_mean,
        "mean_2sigma": AS3_2sigma,
        "color": "darkblue",
        "label": "Duluth area anorthositic series (AS3)",
    },
    {
        "name": "FC_1",
        "df": FC_1,
        "date_col": "206Pb/238U_date",
        "sigma_col": "206Pb/238U_date_2sigma",
        "mean": FC1_mean,
        "mean_2sigma": FC1_2sigma,
        "color": "darkblue",
        "label": "Forest Center anorthositic series (FC-1)",
    },
    {
        "name": "FC_4b",
        "df": FC_4b,
        "date_col": "206Pb/238U_date",
        "sigma_col": "206Pb/238U_date_2sigma",
        "mean": FC4b_mean,
        "mean_2sigma": FC4b_2sigma,
        "color": "darkblue",
        "label": "Forest Center anorthositic series (FC-4b)",
    },
    {
        "name": "HCT",
        "df": HCT,
        "date_col": "206Pb/238U_date",
        "sigma_col": "206Pb/238U_date_2sigma",
        "mean": HCT_mean,
        "mean_2sigma": HCT_2sigma,
        "color": "darkblue",
        "label": "Houghtaling Creek troctolite",
    },
    {
        "name": "MS99033",
        "df": MS99033,
        "date_col": "206Pb/238U",
        "sigma_col": "206Pb/238U_2sigma",
        "mean": 1091.83,
        "mean_2sigma": 0.21,
        "color": "darkblue",
        "label": "Silver Bay Anorthosite xenolith",
    },
    {
        "name": "WLFG",
        "df": WLFG,
        "date_col": "206Pb/238U_date",
        "sigma_col": "206Pb/238U_date_2sigma",
        "mean": WLFG_mean,
        "mean_2sigma": WLFG_2sigma,
        "color": "darkblue",
        "label": "Wilson Lake ferrogabbro",
    },
    {
        "name": "BBC_SBA1",
        "df": BBC_SBA1,
        "date_col": "206Pb/238U",
        "sigma_col": "206Pb/238U_2sigma",
        "mean": 1091.61,
        "mean_2sigma": 0.14,
        "color": "darkblue",
        "label": "Silver Bay Aplite",
    },
]

# --- Build the DataFrame in a way that can't misalign means/sigmas ---

rows = []
for s in samples:
    rows.append(
        {
            "labels": s["label"],
            "polarity_colors": s["color"],
            "U_Pb_zircon_dates": s["df"][s["date_col"]].tolist(),
            "U_Pb_zircon_2sigmas": s["df"][s["sigma_col"]].tolist(),
            "U_Pb_zircon_include": s["df"]["include"].tolist(),
            "U_Pb_sample_mean": s["mean"],
            "U_Pb_sample_2sigma": s["mean_2sigma"],
        }
    )

MCR_geochron = pd.DataFrame(rows)
MCR_geochron.to_csv('./code_output/MCR_geochron.csv')
geochron_data = pd.read_csv('./code_output/MCR_geochron.csv')
geochron_data
# Out:
#     Unnamed: 0                                     labels polarity_colors  \
# 0            0                          Red Rock Rhyolite             red
# 1            1                       Agate Point Rhyolite             red
# 2            2                             Flour Bay tuff             red
# 3            3                   Kallander Creek Rhyolite            blue
# 4            4                        40th Ave Icelandite            blue
# 5            5                     Two Harbors Icelandite            blue
# 6            6                          Palisade Rhyolite            blue
# 7            7                      Grand Marais Rhyolite            blue
# 8            8                           Copper City Flow            blue
# 9            9                            Greenstone Flow            blue
# 10          10                   Lake Shore Trap andesite            blue
# 11          11                         West Sand Bay Tuff            blue
# 12          12                    Davieux Island Rhyolite            blue
# 13          13                  Partridge River intrusion        darkblue
# 14          14                       Bald Eagle intrusion        darkblue
# 15          15      Duluth area anorthositic series (AS3)        darkblue
# 16          16   Forest Center anorthositic series (FC-1)        darkblue
# 17          17  Forest Center anorthositic series (FC-4b)        darkblue
# 18          18               Houghtaling Creek troctolite        darkblue
# 19          19            Silver Bay Anorthosite xenolith        darkblue
# 20          20                    Wilson Lake ferrogabbro        darkblue
# 21          21                          Silver Bay Aplite        darkblue
#
#                                     U_Pb_zircon_dates  \
# 0   [1108.411461, 1106.18172, 1105.755822, 1105.50...
# 1   [1106.5, 1106.0, 1105.66, 1105.41, 1105.05, 11...
# 2   [1104.773494, 1103.700548, 1101.560071, 1101.0...
# 3   [1098.648832, 1098.337682, 1098.17126, 1097.60...
# 4   [1098.58, 1097.46, 1097.18, 1096.88, 1096.81, ...
# 5       [1097.33, 1096.44, 1096.27, 1096.08, 1095.74]
# 6   [1096.29, 1094.66, 1094.47, 1094.34, 1094.19, ...
# 7   [1094.516507, 1093.982532, 1093.618017, 1093.3...
# 8   [1095.63, 1093.59, 1093.23, 1093.14, 1090.97, ...
# 9   [1092.64, 1091.71, 1091.65, 1091.62, 1091.32, ...
# 10  [1089.659441, 1086.717353, 1086.623345, 1086.0...
# 11  [1089.13797, 1084.735324, 1084.506762, 1084.34...
# 12  [1087.406351, 1084.114818, 1083.748997, 1083.4...
# 13  [1096.3692956957627, 1096.3411986087767, 1096....
# 14  [1096.1747761266788, 1096.0388091332786, 1095....
# 15  [1096.23, 1096.09, 1095.97, 1095.94, 1095.8, 1...
# 16  [1096.2692620731762, 1096.190625997245, 1095.9...
# 17  [1095.8461922193035, 1095.8358206391165, 1095....
# 18  [1095.664310374369, 1095.613548461745, 1095.29...
# 19  [1091.971169, 1091.963826, 1091.940206, 1091.8...
# 20  [1091.851708622979, 1091.8099974724937, 1091.6...
# 21  [1091.766875, 1091.664987, 1091.482674, 1091.4...
#
#                                   U_Pb_zircon_2sigmas  \
# 0   [1.168486173, 0.85697308, 0.94457975, 0.456200...
# 1   [2.21, 0.98, 1.29, 0.63, 0.71, 1.45, 1.91, 0.6...
# 2   [1.896362749, 0.866898118, 0.441113108, 1.2440...
# 3   [0.766055169, 0.905348034, 1.129440418, 0.9100...
# 4      [2.72, 0.73, 0.95, 0.7, 0.8, 0.67, 0.64, 0.99]
# 5                       [0.71, 0.57, 0.59, 0.7, 0.71]
# 6     [1.53, 0.69, 0.77, 0.7, 1.14, 1.09, 0.87, 0.49]
# 7   [1.274182098, 1.50419191, 1.823082731, 0.78471...
# 8                 [0.57, 0.76, 1.37, 0.85, 0.5, 0.59]
# 9                [0.94, 0.52, 0.75, 0.95, 0.67, 0.49]
# 10  [2.963291089, 1.017639222, 0.756765685, 0.5990...
# 11  [2.091226565, 1.048717587, 0.333916962, 0.3113...
# 12  [1.302853519, 1.013031741, 0.666917951, 0.5017...
# 13  [0.4540650746678668, 0.44939847012038203, 0.45...
# 14  [0.4484241145264616, 0.45859332803922687, 0.48...
# 15    [0.88, 0.58, 0.5, 0.49, 0.49, 0.46, 0.49, 0.57]
# 16  [0.5108447698370121, 0.5053458354644664, 0.509...
# 17  [0.46875239873114355, 0.4659085093712412, 0.47...
# 18  [0.4670155927134175, 0.5158799382054571, 0.602...
# 19  [0.774118697, 0.45739525, 0.459814406, 0.55184...
# 20  [0.4925351441420653, 1.3504666868452266, 1.145...
# 21  [0.318121361, 0.298447953, 0.354731588, 0.3789...
#
#                                   U_Pb_zircon_include  U_Pb_sample_mean  \
# 0           ['no', 'yes', 'yes', 'yes', 'yes', 'yes']       1105.600000
# 1   ['yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'ye...       1105.150000
# 2   ['no', 'no', 'no', 'yes', 'yes', 'yes', 'yes',...       1100.360000
# 3                        ['yes', 'yes', 'yes', 'yes']       1098.240000
# 4   ['no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes...       1096.750000
# 5                  ['no', 'yes', 'yes', 'yes', 'yes']       1096.180000
# 6   ['no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes...       1093.940000
# 7          ['yes', 'yes', 'yes', 'yes', 'yes', 'yes']       1093.520000
# 8             ['no', 'yes', 'yes', 'yes', 'no', 'no']       1093.370000
# 9          ['yes', 'yes', 'yes', 'yes', 'yes', 'yes']       1091.590000
# 10  ['no', 'no', 'no', 'yes', 'yes', 'yes', 'yes',...       1085.570000
# 11  ['no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes...       1084.350000
# 12          ['no', 'yes', 'yes', 'yes', 'yes', 'yes']       1083.520000
# 13         ['yes', 'yes', 'yes', 'yes', 'yes', 'yes']       1096.194915
# 14         ['yes', 'yes', 'yes', 'yes', 'yes', 'yes']       1095.884576
# 15  ['yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'ye...       1095.862213
# 16  ['yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'ye...       1095.806484
# 17  ['yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'ye...       1095.689963
# 18  ['yes', 'yes', 'yes', 'yes', 'no', 'no', 'no',...       1095.437962
# 19  ['yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no...       1091.830000
# 20  ['yes', 'yes', 'yes', 'yes', 'yes', 'no', 'no'...       1091.628806
# 21         ['yes', 'yes', 'yes', 'yes', 'yes', 'yes']       1091.610000
#
#     U_Pb_sample_2sigma
# 0             0.320000
# 1             0.330000
# 2             0.250000
# 3             0.450000
# 4             0.280000
# 5             0.320000
# 6             0.280000
# 7             0.430000
# 8             0.530000
# 9             0.270000
# 10            0.250000
# 11            0.200000
# 12            0.230000
# 13            0.188294
# 14            0.190780
# 15            0.187112
# 16            0.158034
# 17            0.178937
# 18            0.258533
# 19            0.210000
# 20            0.348412
# 21            0.140000

# %% [markdown]
# ## Add geochronology data to figure in style of Swanson-Hysell et al. (2019) date bar plot

# %% [markdown]
# ## Generate geochronology figure for manuscript

# %%
fig, ax, x_positions = plot_dates(MCR_geochron.U_Pb_zircon_dates, MCR_geochron.U_Pb_zircon_2sigmas, 
                                  MCR_geochron.U_Pb_zircon_include, 
                                  MCR_geochron.U_Pb_sample_mean, MCR_geochron.U_Pb_sample_2sigma, 
                                  MCR_geochron.polarity_colors, MCR_geochron.labels, legend=False, figsize=(14,7), lineweight=2)

max_x_value = 254
ax.set_xlim(0,max_x_value)
ax.set_xticks([])
ax.set_yticks(np.arange(1084,1110,4))
ax.set_yticklabels(np.arange(1084,1110,4),fontsize=12)
ax.yaxis.label.set_size(16)
ax.set_ylim(1108,1082.5)

ax.text(x_positions[0]+1,1105.60-2,'NSVG-RRR \n$\mathit{lower\;NE\;NSVG}$',size='11',horizontalalignment='right',
         verticalalignment='bottom',multialignment='left',rotation=90)
ax.text(x_positions[1],1105.15-3.25,'AP71 \n$\mathit{Osler\;Group}$',size='11',horizontalalignment='right',
        verticalalignment='bottom',multialignment='left',rotation=90)
ax.text(x_positions[2],1100.36-2.5,'MP111-182 \n$\mathit{Mamainse\;Point}$',size='11',horizontalalignment='right',
        verticalalignment='bottom',multialignment='left',rotation=90)
ax.text(x_positions[3],1098.24-2,'CF1 \n$\mathit{Kallander\;Creek\;Volcs.}$',size='11',horizontalalignment='right',
        verticalalignment='bottom',multialignment='left',rotation=90)
ax.text(x_positions[4],1096.75-2.2,'NSVG-40I \n$\mathit{upper\;SW\;NSVG}$',size='11',horizontalalignment='right',
        verticalalignment='bottom',multialignment='left',rotation=90)
ax.text(x_positions[5],1096.18-2,'NSVG-TH1 \n$\mathit{upper\;SW\;NSVG}$',size='11',horizontalalignment='right',
        verticalalignment='bottom',multialignment='left',rotation=90)
ax.text(x_positions[6],1093.94-2,'NSVG-PR1/2 \n$\mathit{upper\;SW\;NSVG}$',size='11',horizontalalignment='right',
        verticalalignment='bottom',multialignment='left',rotation=90)
ax.text(x_positions[7],1093.52-2,'NSVG-GMR1 \n$\mathit{upper\;NE\;NSVG}$',size='11',horizontalalignment='right',
        verticalalignment='bottom',multialignment='left',rotation=90)
ax.text(x_positions[8],1093.37-2,'PLV-CC1 \n$\mathit{Portage\;Lake\;Volcs.}$',size='11',horizontalalignment='right',
        verticalalignment='bottom',multialignment='left',rotation=90)
ax.text(x_positions[9],1091.59-1.5,'PLV-GS1 \n$\mathit{Portage\;Lake\;Volcs.}$',size='11',horizontalalignment='right',
        verticalalignment='bottom',multialignment='left',rotation=90)
ax.text(x_positions[10],1085.57+1.5,'LST-KP1\n$\mathit{Lake\;Shore\;Traps}$',size='11',horizontalalignment='right',
        verticalalignment='top',multialignment='right',rotation=90)
ax.text(x_positions[11]-2,1084.35+1.5,'MI-WSB1\n$\mathit{Michipicoten\;Volcs.}$',size='11',horizontalalignment='right',
        verticalalignment='top',multialignment='right',rotation=90)
ax.text(x_positions[12],1083.52+1.5,'MI-DI1\n$\mathit{Michipicoten\;Volcs.}$',size='11',horizontalalignment='right',
        verticalalignment='top',multialignment='right',rotation=90)
ax.text(x_positions[13],1096.19+1.2,'PRI (layered)\n1096.19 $\pm$ 0.19 Ma',size='11',horizontalalignment='right',
        verticalalignment='top',multialignment='right',rotation=90)
ax.text(x_positions[14],1095.89+1.2,'BEI (layered)\n1095.89 $\pm$ 0.19 Ma',size='11',horizontalalignment='right',
        verticalalignment='top',multialignment='right',rotation=90)
ax.text(x_positions[15],1095.86+1.2,'AS3 (anorthositic)\n1095.86 $\pm$ 0.19 Ma',size='11',horizontalalignment='right',
        verticalalignment='top',multialignment='right',rotation=90)
ax.text(x_positions[16],1095.81+1.2,'FC1 (anorthositic)\n1095.81 $\pm$ 0.16 Ma',size='11',horizontalalignment='right',
        verticalalignment='top',multialignment='right',rotation=90)
ax.text(x_positions[17],1095.71+1.2,'FC4b (anorthositic)\n1095.69 $\pm$ 0.18 Ma',size='11',horizontalalignment='right',
        verticalalignment='top',multialignment='right',rotation=90)
ax.text(x_positions[18],1095.44+1.2,'HCT\n1095.44 $\pm$ 0.26 Ma',size='11',horizontalalignment='right',
        verticalalignment='top',multialignment='right',rotation=90)
ax.text(x_positions[19]+0.5,1091.83-1.5,'MS99033 \n1091.83 $\pm$ 0.21 Ma',size='11',horizontalalignment='right',
        verticalalignment='bottom',multialignment='left',rotation=90)
ax.text(x_positions[20]+0.5,1091.63-1.5,'WLFG \n1091.63 $\pm$ 0.35 Ma',size='11',horizontalalignment='right',
        verticalalignment='bottom',multialignment='left',rotation=90)
ax.text(x_positions[21]+0.5,1091.61-1.5,'BBC-SBA1\n1091.61 $\pm$ 0.14 Ma',size='11',horizontalalignment='right',
        verticalalignment='bottom',multialignment='left',rotation=90)

rectangle = matplotlib.patches.Rectangle((0,1095.71 - 0.17),300, (1096.19 + 0.19)-(1095.71 - 0.17), color='lightgreen',alpha=0.35)
ax.add_patch(rectangle)
ax.text(max_x_value-0.75, 1096.19 + 0.19 + 0.45, 'Duluth\nComplex\nlayered &\nanorthositic\nseries', color='green' ,size='11',
        verticalalignment='top',horizontalalignment='right')

rectangle = matplotlib.patches.Rectangle((0,1091.63 - 0.35),300, (1091.63 + 0.35)-(1091.63 - 0.35), color='orange',alpha=0.25)
ax.add_patch(rectangle)
ax.text(max_x_value-0.75, 1091.63 + 0.35 + 0.45, 'Beaver\nBay\nComplex', color='darkorange' ,size='11',
        verticalalignment='top', horizontalalignment='right')

ext_int_split = 147
plt.vlines(ext_int_split,1110,1000,linewidths=1,linestyle='--')
plt.text(ext_int_split-2,1107.5,'Volcanics',horizontalalignment='right',fontsize=16)
plt.text(ext_int_split+2,1107.5,'Intrusives',horizontalalignment='left',fontsize=16)

plt.hlines(1098.5,x_positions[3]+6,x_positions[6])
plt.text((x_positions[3]+6+x_positions[6])/2,1099,'upper southwest\nsequence of\nthe North Shore\nVolcanic Group\n(7900 m thick)',verticalalignment='top',
         horizontalalignment='center',fontsize=14)

plt.hlines(1093.8,x_positions[12]+3,x_positions[17])
plt.text((x_positions[12]+3+x_positions[17])/2,1093.2,'Duluth Complex',horizontalalignment='center',fontsize=14)

legend_elements = [Patch(facecolor='lightgrey', edgecolor=None,
                         label='Weighted mean dates'),
                   Line2D([], [],  marker='|', linestyle='None', color='red', label='Reversed-polarity volcanics',
                          markerfacecolor='k', markersize=10, markeredgewidth=3),
                   Line2D([], [],  marker='|', linestyle='None', color='blue', label='Normal-polarity volcanics',
                          markerfacecolor='k', markersize=10, markeredgewidth=3),
                   Line2D([], [],  marker='|', linestyle='None', color='darkblue', label='Normal-polarity intrusives',
                          markerfacecolor='k', markersize=10, markeredgewidth=3)]

plt.legend(handles=legend_elements, loc='upper right',
           bbox_to_anchor=(.865,1), fancybox=True, fontsize = 12)

plt.savefig('./code_output/MCR_dates.pdf',bbox_inches='tight')
plt.show(fig)
